# %%
# 本代码由可视化策略环境自动生成 2019年5月11日 12:10
# 本代码单元只能在可视化模式下编辑。您也可以拷贝代码，粘贴到新建的代码单元或者策略，然后修改。


m1 = M.single_factor_analysis.v2(
    factor='market_cap_float_0',
    start_date='2014-01-01',
    end_date='2019-03-31'
)
# Out:
# [2019-05-11 10:19:51.442469] INFO: bigquant: single_factor_analysis.v2 开始运行..
# [2019-05-11 10:19:51.490899] INFO: bigquant: 命中缓存
# market_cap_float_0
# <div id="bigchart-055cd2b36a8e4c13b0d73d6b67bd642f" class="bigchart"></div><div class="bigchart-data"><pre style="display:none">bigcharts-data-start/{"series":[{"name":"market_cap_float_0","yAxis":0,"data":[[1,2.526e-16],[2,1.638e-16],[3,-1.044e-16],[4,2.174e-16],[5,1.031e-17],[6,-6.108e-17],[7,9.996e-17],[8,-6.042e-17],[9,4.967e-17],[10,1.875e-16],[11,7.518e-17],[12,1.501e-16]]}],"legend":{"enabled":false},"title":{"text":"\u56e0\u5b50\u66b4\u9732\u6708\u5206\u5e03"},"stock":false,"chart":{"renderTo":"bigchart-055cd2b36a8e4c13b0d73d6b67bd642f","height":500,"type":"column"},"xAxis":{"title":{"text":"date"}}}/bigcharts-data-end</pre></div>
# ...
