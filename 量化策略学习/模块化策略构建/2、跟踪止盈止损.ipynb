# %%
# 本代码由可视化策略环境自动生成 2019年5月9日 10:51
# 本代码单元只能在可视化模式下编辑。您也可以拷贝代码，粘贴到新建的代码单元或者策略，然后修改。


# 回测引擎：每日数据处理函数，每天执行一次
def m19_handle_data_bigquant_run(context, data):

 #------------------------------------------跟踪止损模块START--------------------------------------------
    date = data.current_dt.strftime('%Y-%m-%d')  
    equities = {e.symbol: p for e, p in context.portfolio.positions.items() if p.amount>0}
    # 新建当日止损股票列表是为了handle_data 策略逻辑部分不再对该股票进行判断
    current_stoploss_stock = [] 
    if len(equities) > 0:
        for i in equities.keys():
            stock_market_price = data.current(context.symbol(i), 'price')  # 最新市场价格
            last_sale_date = equities[i].last_sale_date   # 上次交易日期
            delta_days = data.current_dt - last_sale_date  
            hold_days = delta_days.days # 持仓天数
            # 建仓以来的最高价
            highest_price_since_buy = data.history(context.symbol(i), 'high', hold_days, '1d').max()
            # 确定止损位置
            stoploss_line = highest_price_since_buy - highest_price_since_buy * 0.1
            record('止损位置', stoploss_line)
            # 如果价格下穿止损位置
            if stock_market_price < stoploss_line:
                context.order_target_percent(context.symbol(i), 0)     
                current_stoploss_stock.append(i)
                print('日期：', date , '股票：', i, '出现止损状况')
    #-------------------------------------------跟踪止损模块END-------------------------------

    
    
    # 按日期过滤得到今日的预测数据
    ranker_prediction = context.ranker_prediction[
        context.ranker_prediction.date == data.current_dt.strftime('%Y-%m-%d')]

    # 1. 资金分配
    # 平均持仓时间是hold_days，每日都将买入股票，每日预期使用 1/hold_days 的资金
    # 实际操作中，会存在一定的买入误差，所以在前hold_days天，等量使用资金；之后，尽量使用剩余资金（这里设置最多用等量的1.5倍）
    is_staging = context.trading_day_index < context.options['hold_days'] # 是否在建仓期间（前 hold_days 天）
    cash_avg = context.portfolio.portfolio_value / context.options['hold_days']
    cash_for_buy = min(context.portfolio.cash, (1 if is_staging else 1.5) * cash_avg)
    cash_for_sell = cash_avg - (context.portfolio.cash - cash_for_buy)
    positions = {e.symbol: p.amount * p.last_sale_price
                 for e, p in context.portfolio.positions.items()}

    # 2. 生成卖出订单：hold_days天之后才开始卖出；对持仓的股票，按机器学习算法预测的排序末位淘汰
    if not is_staging and cash_for_sell > 0:
        equities = {e.symbol: e for e, p in context.portfolio.positions.items()}
        instruments = list(reversed(list(ranker_prediction.instrument[ranker_prediction.instrument.apply(
                lambda x: x in equities)])))

        for instrument in instruments:
            # 这里进行过滤，如果已经跟踪止损卖出了就不再执行轮仓卖出逻辑
            if instrument in current_stoploss_stock:
                continue
            context.order_target(context.symbol(instrument), 0)
            cash_for_sell -= positions[instrument]
            if cash_for_sell <= 0:
                break

    # 3. 生成买入订单：按机器学习算法预测的排序，买入前面的stock_count只股票
    buy_cash_weights = context.stock_weights
    buy_instruments = list(ranker_prediction.instrument[:len(buy_cash_weights)])
    max_cash_per_instrument = context.portfolio.portfolio_value * context.max_cash_per_instrument
    for i, instrument in enumerate(buy_instruments):
        cash = cash_for_buy * buy_cash_weights[i]
        if cash > max_cash_per_instrument - positions.get(instrument, 0):
            # 确保股票持仓量不会超过每次股票最大的占用资金量
            cash = max_cash_per_instrument - positions.get(instrument, 0)
        if cash > 0:
            context.order_value(context.symbol(instrument), cash)

# 回测引擎：准备数据，只执行一次
def m19_prepare_bigquant_run(context):
    pass

# 回测引擎：初始化函数，只执行一次
def m19_initialize_bigquant_run(context):
    # 加载预测数据
    context.ranker_prediction = context.options['data'].read_df()

    # 系统已经设置了默认的交易手续费和滑点，要修改手续费可使用如下函数
    context.set_commission(PerOrder(buy_cost=0.0003, sell_cost=0.0013, min_cost=5))
    # 预测数据，通过options传入进来，使用 read_df 函数，加载到内存 (DataFrame)
    # 设置买入的股票数量，这里买入预测股票列表排名靠前的5只
    stock_count = 5
    # 每只的股票的权重，如下的权重分配会使得靠前的股票分配多一点的资金，[0.339160, 0.213986, 0.169580, ..]
    context.stock_weights = T.norm([1 / math.log(i + 2) for i in range(0, stock_count)])
    # 设置每只股票占用的最大资金比例
    context.max_cash_per_instrument = 0.2
    context.options['hold_days'] = 5


m1 = M.instruments.v2(
    start_date='2010-01-01',
    end_date='2015-01-01',
    market='CN_STOCK_A',
    instrument_list='',
    max_count=0
)

m2 = M.advanced_auto_labeler.v2(
    instruments=m1.data,
    label_expr="""# #号开始的表示注释
# 0. 每行一个，顺序执行，从第二个开始，可以使用label字段
# 1. 可用数据字段见 https://bigquant.com/docs/develop/datasource/deprecated/history_data.html
#   添加benchmark_前缀，可使用对应的benchmark数据
# 2. 可用操作符和函数见 `表达式引擎 <https://bigquant.com/docs/develop/bigexpr/usage.html>`_

# 计算收益：5日收盘价(作为卖出价格)除以明日开盘价(作为买入价格)
shift(close, -5) / shift(open, -1)

# 极值处理：用1%和99%分位的值做clip
clip(label, all_quantile(label, 0.01), all_quantile(label, 0.99))

# 将分数映射到分类，这里使用20个分类
all_wbins(label, 20)

# 过滤掉一字涨停的情况 (设置label为NaN，在后续处理和训练中会忽略NaN的label)
where(shift(high, -1) == shift(low, -1), NaN, label)
""",
    start_date='',
    end_date='',
    benchmark='000300.SHA',
    drop_na_label=True,
    cast_label_int=True
)

m3 = M.input_features.v1(
    features="""# #号开始的表示注释
# 多个特征，每行一个，可以包含基础特征和衍生特征
return_5
return_10
return_20
avg_amount_0/avg_amount_5
avg_amount_5/avg_amount_20
rank_avg_amount_0/rank_avg_amount_5
rank_avg_amount_5/rank_avg_amount_10
rank_return_0
rank_return_5
rank_return_10
rank_return_0/rank_return_5
rank_return_5/rank_return_10
pe_ttm_0
"""
)

m15 = M.general_feature_extractor.v7(
    instruments=m1.data,
    features=m3.data,
    start_date='',
    end_date='',
    before_start_days=0
)

m16 = M.derived_feature_extractor.v3(
    input_data=m15.data,
    features=m3.data,
    date_col='date',
    instrument_col='instrument',
    drop_na=False,
    remove_extra_columns=False
)

m7 = M.join.v3(
    data1=m2.data,
    data2=m16.data,
    on='date,instrument',
    how='inner',
    sort=False
)

m13 = M.dropnan.v1(
    input_data=m7.data
)

m6 = M.stock_ranker_train.v5(
    training_ds=m13.data,
    features=m3.data,
    learning_algorithm='排序',
    number_of_leaves=30,
    minimum_docs_per_leaf=1000,
    number_of_trees=20,
    learning_rate=0.1,
    max_bins=1023,
    feature_fraction=1,
    m_lazy_run=False
)

m9 = M.instruments.v2(
    start_date=T.live_run_param('trading_date', '2015-01-01'),
    end_date=T.live_run_param('trading_date', '2017-01-01'),
    market='CN_STOCK_A',
    instrument_list='',
    max_count=0
)

m17 = M.general_feature_extractor.v7(
    instruments=m9.data,
    features=m3.data,
    start_date='',
    end_date='',
    before_start_days=0
)

m18 = M.derived_feature_extractor.v3(
    input_data=m17.data,
    features=m3.data,
    date_col='date',
    instrument_col='instrument',
    drop_na=False,
    remove_extra_columns=False
)

m14 = M.dropnan.v1(
    input_data=m18.data
)

m8 = M.stock_ranker_predict.v5(
    model=m6.model,
    data=m14.data,
    m_lazy_run=False
)

m19 = M.trade.v4(
    instruments=m9.data,
    options_data=m8.predictions,
    start_date='',
    end_date='',
    handle_data=m19_handle_data_bigquant_run,
    prepare=m19_prepare_bigquant_run,
    initialize=m19_initialize_bigquant_run,
    volume_limit=0.025,
    order_price_field_buy='open',
    order_price_field_sell='close',
    capital_base=1000000,
    auto_cancel_non_tradable_orders=True,
    data_frequency='daily',
    price_type='后复权',
    product_type='股票',
    plot_charts=True,
    backtest_only=False,
    benchmark='000300.SHA'
)
# Out:
# [2019-05-09 10:51:17.567012] INFO: bigquant: instruments.v2 开始运行..
# [2019-05-09 10:51:17.609600] INFO: bigquant: 命中缓存
# [2019-05-09 10:51:17.612426] INFO: bigquant: instruments.v2 运行完成[0.045418s].
# [2019-05-09 10:51:17.616471] INFO: bigquant: advanced_auto_labeler.v2 开始运行..
# [2019-05-09 10:51:17.642191] INFO: bigquant: 命中缓存
# [2019-05-09 10:51:17.644021] INFO: bigquant: advanced_auto_labeler.v2 运行完成[0.027544s].
# [2019-05-09 10:51:17.660582] INFO: bigquant: input_features.v1 开始运行..
# [2019-05-09 10:51:17.707667] INFO: bigquant: 命中缓存
# [2019-05-09 10:51:17.710074] INFO: bigquant: input_features.v1 运行完成[0.049498s].
# [2019-05-09 10:51:17.764745] INFO: bigquant: general_feature_extractor.v7 开始运行..
# [2019-05-09 10:51:17.835193] INFO: bigquant: 命中缓存
# [2019-05-09 10:51:17.837625] INFO: bigquant: general_feature_extractor.v7 运行完成[0.072883s].
# [2019-05-09 10:51:17.841626] INFO: bigquant: derived_feature_extractor.v3 开始运行..
# [2019-05-09 10:51:17.983626] INFO: bigquant: 命中缓存
# [2019-05-09 10:51:17.986170] INFO: bigquant: derived_feature_extractor.v3 运行完成[0.144533s].
# [2019-05-09 10:51:17.990707] INFO: bigquant: join.v3 开始运行..
# [2019-05-09 10:51:18.045972] INFO: bigquant: 命中缓存
# [2019-05-09 10:51:18.048636] INFO: bigquant: join.v3 运行完成[0.057923s].
# [2019-05-09 10:51:18.056823] INFO: bigquant: dropnan.v1 开始运行..
# [2019-05-09 10:51:18.088394] INFO: bigquant: 命中缓存
# [2019-05-09 10:51:18.090069] INFO: bigquant: dropnan.v1 运行完成[0.033246s].
# [2019-05-09 10:51:18.093945] INFO: bigquant: stock_ranker_train.v5 开始运行..
# [2019-05-09 10:51:18.177416] INFO: bigquant: 命中缓存
# <div id='bigchart-f5d50c8a8f7b4963a52397a620fcef6e' class='bigchart display' style='display:none'><ul class='nav nav-tabs' style='padding-left: 0;'><li class='tabtitle' style='margin: 0;'><span style='margin: 0;font-size: 1.2em;display: inline-block;padding: 10px 10px;'>StockRanker</span></li><li class='active'><a>特征重要性</a></li><li><a>模型</a></li><li><a>NDCG</a></li></ul><div class='tab-content' style='min-height: 100px;text-align: center;'><div class='tab-pane active' id='特征重要性'><div id="bigchart-cb391092b71f4cd7b1498a03a45511fc" class="bigchart"></div><div class="bigchart-data"><pre style="display:none">bigcharts-data-start/{"title":{"text":"\u7279\u5f81\u91cd\u8981\u6027"},"chart":{"type":"column","height":400,"renderTo":"bigchart-cb391092b71f4cd7b1498a03a45511fc"},"legend":{"enabled":true},"stock":false,"xAxis":{"categories":["rank_avg_amount_5\/rank_avg_amount_10","rank_return_5","rank_return_0","return_20","rank_avg_amount_0\/rank_avg_amount_5","rank_return_10","rank_return_0\/rank_return_5","rank_return_5\/rank_return_10","pe_ttm_0","return_10","avg_amount_5\/avg_amount_20","avg_amount_0\/avg_amount_5","return_5"],"title":{"text":"\u7279\u5f81"}},"series":[{"name":"\u7279\u5f81\u91cd\u8981\u6027","data":[["rank_avg_amount_5\/rank_avg_amount_10",650.0526],["rank_return_5",417.1644],["rank_return_0",283.3318],["return_20",165.3231],["rank_avg_amount_0\/rank_avg_amount_5",148.0715],["rank_return_10",99.2575],["rank_return_0\/rank_return_5",65.2453],["rank_return_5\/rank_return_10",65.1305],["pe_ttm_0",39.8848],["return_10",27.1068],["avg_amount_5\/avg_amount_20",19.9068],["avg_amount_0\/avg_amount_5",16.8924],["return_5",10.942]],"yAxis":0}]}/bigcharts-data-end</pre></div></div><div class='tab-pane' id='模型'><div id="bigchart-cb9ac47f506c4a5ca87d84924d7c306b" class="bigchart"></div><div class="bigchart-data"><pre style="display:none">bigcharts-data-start/{"tips":"sum()","c":[{"c":[{"c":[{"c":[{"c":[{"c":[{"c":[{"v":"-0.199"},{"v":"-0.038"}],"v":5.5,"f":5},{"c":[{"c":[{"v":"0.1054"},{"c":[{"v":"0.0625"},{"v":"-0.027"}],"v":822.5,"f":6}],"v":236.5,"f":7},{"v":"0.1337"}],"v":723.5,"f":7}],"v":65.5,"f":5},{"c":[{"v":"-0.054"},{"v":"0.0177"}],"v":776.5,"f":4}],"v":859.5,"f":2},{"c":[{"c":[{"v":"-0.053"},{"v":"-0.131"}],"v":803.5,"f":8},{"v":"0.0025"}],"v":741.5,"f":7}],"v":794.5,"f":1},{"c":[{"c":[{"
# [2019-05-09 10:51:18.424831] INFO: bigquant: general_feature_extractor.v7 运行完成[0.032395s].
# [2019-05-09 10:51:18.428588] INFO: bigquant: derived_feature_extractor.v3 开始运行..
# [2019-05-09 10:51:18.463777] INFO: bigquant: 命中缓存
# [2019-05-09 10:51:18.466200] INFO: bigquant: derived_feature_extractor.v3 运行完成[0.037599s].
# [2019-05-09 10:51:18.469958] INFO: bigquant: dropnan.v1 开始运行..
# [2019-05-09 10:51:18.511248] INFO: bigquant: 命中缓存
# [2019-05-09 10:51:18.513712] INFO: bigquant: dropnan.v1 运行完成[0.043743s].
# [2019-05-09 10:51:18.518874] INFO: bigquant: stock_ranker_predict.v5 开始运行..
# [2019-05-09 10:51:18.560860] INFO: bigquant: 命中缓存
# [2019-05-09 10:51:18.563696] INFO: bigquant: stock_ranker_predict.v5 运行完成[0.044808s].
# [2019-05-09 10:51:18.614683] INFO: bigquant: backtest.v8 开始运行..
# [2019-05-09 10:51:18.618080] INFO: bigquant: biglearning backtest:V8.1.14
# [2019-05-09 10:51:18.619676] INFO: bigquant: product_type:stock by specified
# [2019-05-09 10:51:18.858625] INFO: bigquant: cached.v2 开始运行..
# [2019-05-09 10:51:18.901120] INFO: bigquant: 命中缓存
# [2019-05-09 10:51:18.903780] INFO: bigquant: cached.v2 运行完成[0.045154s].
# [2019-05-09 10:51:28.484581] INFO: algo: TradingAlgorithm V1.4.12
# [2019-05-09 10:51:38.864684] INFO: algo: trading transform...
# 日期： 2015-02-02 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-03 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-04 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-05 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-06 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-09 股票： 002240.SZA 出现止损状况
# 日期： 2015-02-09 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-10 股票： 002240.SZA 出现止损状况
# 日期： 2015-02-10 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-11 股票： 002240.SZA 出现止损状况
# 日期： 2015-02-11 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-12 股票： 002240.SZA 出现止损状况
# 日期： 2015-02-12 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-13 股票： 002240.SZA 出现止损状况
# 日期： 2015-02-13 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-16 股票： 002240.SZA 出现止损状况
# 日期： 2015-02-16 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-17 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-17 股票： 002240.SZA 出现止损状况
# 日期： 2015-02-25 股票： 300210.SZA 出现止损状况
# 日期： 2015-02-25 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-26 股票： 600212.SHA 出现止损状况
# 日期： 2015-02-27 股票： 600212.SHA 出现止损状况
# 日期： 2015-03-02 股票： 600212.SHA 出现止损状况
# 日期： 2015-03-03 股票： 600212.SHA 出现止损状况
# 日期： 2015-03-04 股票： 600212.SHA 出现止损状况
# 日期： 2015-03-05 股票： 600212.SHA 出现止损状况
# 日期： 2015-03-06 股票： 600212.SHA 出现止损状况
# 日期： 2015-03-09 股票： 600212.SHA 出现止损状况
# 日期： 2015-03-30 股票： 300291.SZA 出现止损状况
# 日期： 2015-04-20 股票： 002537.SZA 出现止损状况
# 日期： 2015-05-04 股票： 002539.SZA 出现止损状况
# 日期： 2015-05-28 股票： 600721.SHA 出现止损状况
# 日期： 2015-05-28 股票： 002141.SZA 出现止损状况
# 日期： 2015-05-28 股票： 002088.SZA 出现止损状况
# 日期： 2015-05-28 股票： 600679.SHA 出现止损状况
# 日期： 2015-05-28 股票： 600746.SHA 出现止损状况
# 日期： 2015-05-28 股票： 600671.SHA 出现止损状况
# 日期： 2015-05-28 股票： 002619.SZA 出现止损状况
# 日期： 2015-05-28 股票： 002563.SZA 出现止损状况
# 日期： 2015-05-28 股票： 300305.SZA 出现止损状况
# 日期： 2015-05-28 股票： 002534.SZA 出现止损状况
# 日期： 2015-05-29 股票： 600163.SHA 出现止损状况
# 日期： 2015-06-04 股票： 000155.SZA 出现止损状况
# 日期： 2015-06-15 股票： 300302.SZA 出现止损状况
# 日期： 2015-06-16 股票： 002279.SZA 出现止损状况
# 日期： 2015-06-16 股票： 300380.SZA 出现止损状况
# 日期： 2015-06-16 股票： 002124.SZA 出现止损状况
# 日期： 2015-06-18 股票： 300378.SZA 出现止损状况
# 日期： 2015-06-19 股票： 002059.SZA 出现止损状况
# 日期： 2015-06-23 股票： 300077.SZA 出现止损状况
# 日期： 2015-06-23 股票： 002034.SZA 出现止损状况
# 日期： 2015-06-23 股票： 600446.SHA 出现止损状况
# 日期： 2015-06-23 股票： 300359.SZA 出现止损状况
# 日期： 2015-06-25 股票： 300350.SZA 出现止损状况
# 日期： 2015-06-26 股票： 300350.SZA 出现止损状况
# 日期： 2015-06-26 股票： 300270.SZA 出现止损状况
# 日期： 2015-06-26 股票： 002077.SZA 出现止损状况
# 日期： 2015-06-26 股票： 002687.SZA 出现止损状况
# 日期： 2015-06-29 股票： 300151.SZA 出现止损状况
# 日期： 2015-06-29 股票： 002572.SZA 出现止损状况
# 日期： 2015-06-29 股票： 603818.SHA 出现止损状况
# 日期： 2015-06-29 股票： 603869.SHA 出现止损状况
# 日期： 2015-06-29 股票： 002229.SZA 出现止损状况
# 日期： 2015-06-29 股票： 300350.SZA 出现止损状况
# 日期： 2015-06-29 股票： 300270.SZA 出现止损状况
# 日期： 2015-06-29 股票： 002077.SZA 出现止损状况
# 日期： 2015-06-29 股票： 603703.SHA 出现止损状况
# 日期： 2015-06-29 股票： 600446.SHA 出现止损状况
# 日期： 2015-06-29 股票： 002687.SZA 出现止损状况
# 日期： 2015-06-29 股票： 300445.SZA 出现止损状况
# 日期： 2015-06-29 股票： 300075.SZA 出现止损状况
# 日期： 2015-06-30 股票： 002572.SZA 出现止损状况
股票： 002515.SZA 出现止损状况
# 日期： 2015-07-17 股票： 002341.SZA 出现止损状况
# 日期： 2015-07-20 股票： 000662.SZA 出现止损状况
# 日期： 2015-07-20 股票： 002451.SZA 出现止损状况
# 日期： 2015-07-20 股票： 002515.SZA 出现止损状况
# 日期： 2015-07-20 股票： 002341.SZA 出现止损状况
# 日期： 2015-07-20 股票： 002322.SZA 出现止损状况
# 日期： 2015-07-21 股票： 002341.SZA 出现止损状况
# 日期： 2015-07-21 股票： 002451.SZA 出现止损状况
# 日期： 2015-07-21 股票： 002515.SZA 出现止损状况
# 日期： 2015-07-21 股票： 002322.SZA 出现止损状况
# 日期： 2015-07-22 股票： 002451.SZA 出现止损状况
# 日期： 2015-07-22 股票： 002515.SZA 出现止损状况
# 日期： 2015-07-22 股票： 002322.SZA 出现止损状况
# 日期： 2015-07-22 股票： 002341.SZA 出现止损状况
# 日期： 2015-07-23 股票： 002515.SZA 出现止损状况
# 日期： 2015-07-23 股票： 002341.SZA 出现止损状况
# 日期： 2015-07-23 股票： 002322.SZA 出现止损状况
# 日期： 2015-07-24 股票： 002515.SZA 出现止损状况
# 日期： 2015-07-24 股票： 002322.SZA 出现止损状况
# 日期： 2015-07-27 股票： 000517.SZA 出现止损状况
# 日期： 2015-07-27 股票： 002217.SZA 出现止损状况
# 日期： 2015-07-27 股票： 000975.SZA 出现止损状况
# 日期： 2015-07-27 股票： 300431.SZA 出现止损状况
# 日期： 2015-07-27 股票： 600130.SHA 出现止损状况
# 日期： 2015-07-27 股票： 000090.SZA 出现止损状况
# 日期： 2015-07-27 股票： 002515.SZA 出现止损状况
# 日期： 2015-07-27 股票： 002322.SZA 出现止损状况
# 日期： 2015-07-27 股票： 002284.SZA 出现止损状况
# 日期： 2015-07-28 股票： 002217.SZA 出现止损状况
# 日期： 2015-07-28 股票： 300431.SZA 出现止损状况
# 日期： 2015-07-28 股票： 600130.SHA 出现止损状况
# 日期： 2015-07-28 股票： 600242.SHA 出现止损状况
# 日期： 2015-07-28 股票： 002515.SZA 出现止损状况
# 日期： 2015-07-28 股票： 002322.SZA 出现止损状况
# 日期： 2015-07-28 股票： 002284.SZA 出现止损状况
# 日期： 2015-07-29 股票： 002515.SZA 出现止损状况
# 日期： 2015-07-29 股票： 002322.SZA 出现止损状况
# 日期： 2015-07-30 股票： 002322.SZA 出现止损状况
# 日期： 2015-07-30 股票： 002515.SZA 出现止损状况
# 日期： 2015-07-30 股票： 300069.SZA 出现止损状况
# 日期： 2015-07-31 股票： 002515.SZA 出现止损状况
# 日期： 2015-07-31 股票： 300212.SZA 出现止损状况
# 日期： 2015-08-03 股票： 300074.SZA 出现止损状况
# 日期： 2015-08-03 股票： 002664.SZA 出现止损状况
# 日期： 2015-08-03 股票： 000716.SZA 出现止损状况
# 日期： 2015-08-03 股票： 300120.SZA 出现止损状况
# 日期： 2015-08-03 股票： 002515.SZA 出现止损状况
# 日期： 2015-08-03 股票： 300339.SZA 出现止损状况
# 日期： 2015-08-03 股票： 600526.SHA 出现止损状况
# 日期： 2015-08-04 股票： 002515.SZA 出现止损状况
# 日期： 2015-08-04 股票： 000716.SZA 出现止损状况
# 日期： 2015-08-05 股票： 002515.SZA 出现止损状况
# 日期： 2015-08-06 股票： 002339.SZA 出现止损状况
# 日期： 2015-08-06 股票： 002515.SZA 出现止损状况
# 日期： 2015-08-07 股票： 002515.SZA 出现止损状况
# 日期： 2015-08-10 股票： 002515.SZA 出现止损状况
# 日期： 2015-08-11 股票： 002515.SZA 出现止损状况
# 日期： 2015-08-12 股票： 002515.SZA 出现止损状况
# 日期： 2015-08-13 股票： 002515.SZA 出现止损状况
# 日期： 2015-08-14 股票： 002515.SZA 出现止损状况
# 日期： 2015-08-17 股票： 002515.SZA 出现止损状况
# 日期： 2015-08-18 股票： 002487.SZA 出现止损状况
# 日期： 2015-08-18 股票： 002375.SZA 出现止损状况
# 日期： 2015-08-18 股票： 002515.SZA 出现止损状况
# 日期： 2015-09-02 股票： 002115.SZA 出现止损状况
# 日期： 2015-09-02 股票： 002288.SZA 出现止损状况
# 日期： 2015-09-02 股票： 600376.SHA 出现止损状况
# 日期： 2015-09-02 股票： 300212.SZA 出现止损状况
# 日期： 2015-09-02 股票： 300038.SZA 出现止损状况
# 日期： 2015-09-07 股票： 002617.SZA 出现止损状况
# 日期： 2015-09-07 股票： 600145.SHA 出现止损状况
# 日期： 2015-09-08 股票： 600145.SHA 出现止损状况
# 日期： 2015-09-14 股票： 000628.SZA 出现止损状况
# 日期： 2015-09-14 股票： 300277.SZA 出现止损状况
# 日期： 2015-09-14 股票： 600807.SHA 出现止损状况
# 日期： 2015-09-14 股票： 300032.SZA 出现止损状况
# 日期： 2015-09-14 股票： 002515.SZA 出现止损状况
# 日期： 2015-09-14 股票： 300388.SZA 出现止损状况
# 日期： 2015-09-14 股票： 600184.SHA 出现止损状况
# 日期： 2015-09-14 股票： 300432.SZA 出现止损状况
# 日期： 2015-09-14 股票： 002576.SZA 出现止损状况
# 日期： 2015-09-14 股票： 002190.SZA 出现止损状况
# 日期： 2015-09-14 股票： 300101.SZA 出现止损状况
# 日期： 2015-09-15 股票： 000628.SZA 出现止损状况
# 日期： 2015-09-15 股票： 300277.SZA 出现止损状况
# 日期： 2015-09-15 股票： 300032.SZA 出现止损状况
# 日期： 2015-09-15 股票： 002515.SZA 出现止损状况
# 日期： 2015-09-15 股票： 300388.SZA 出现止损状况
# 日期： 2015-09-15 股票： 600184.SHA 出现止损状况
# 日期： 2015-09-15 股票： 300432.SZA 出现止损状况
# 日期： 2015-09-15 股票： 002190.SZA 出现止损状况
# 日期： 2015-09-15 股票： 300101.SZA 出现止损状况
# 日期： 2015-09-23 股票： 000564.SZA 出现止损状况
# 日期： 2015-09-25 股票： 300128.SZA 出现止损状况
# 日期： 2015-09-29 股票： 603021.SHA 出现止损状况
# 日期： 2015-09-29 股票： 002759.SZA 出现止损状况
# 日期： 2015-10-08 股票： 002217.SZA 出现止损状况
# 日期： 2015-10-08 股票： 000709.SZA 出现止损状况
# 日期： 2015-10-08 股票： 000416.SZA 出现止损状况
# 日期： 2015-10-08 股票： 002592.SZA 出现止损状况
# 日期： 2015-10-21 股票： 600074.SHA 出现止损状况
# 日期： 2015-10-21 股票： 603600.SHA 出现止损状况
# 日期： 2015-10-21 股票： 000782.SZA 出现止损状况
# 日期： 2015-10-21 股票： 002272.SZA 出现止损状况
# 日期： 2015-10-21 股票： 600879.SHA 出现止损状况
# 日期： 2015-10-21 股票： 603017.SHA 出现止损状况
# 日期： 2015-11-27 股票： 600211.SHA 出现止损状况
# 日期： 2015-11-27 股票： 000759.SZA 出现止损状况
# 日期： 2015-11-27 股票： 000920.SZA 出现止损状况
# 日期： 2015-11-30 股票： 600145.SHA 出现止损状况
# 日期： 2015-11-30 股票： 000590.SZA 出现止损状况
# 日期： 2015-11-30 股票： 000611.SZA 出现止损状况
# 日期： 2015-11-30 股票： 000018.SZA 出现止损状况
# 日期： 2015-12-09 股票： 000908.SZA 出现止损状况
# 日期： 2015-12-10 股票： 002577.SZA 出现止损状况
# 日期： 2015-12-10 股票： 002301.SZA 出现止损状况
# 日期： 2015-12-10 股票： 002210.SZA 出现止损状况
# 日期： 2015-12-30 股票： 600643.SHA 出现止损状况
# 日期： 2016-01-04 股票： 300294.SZA 出现止损状况
# 日期： 2016-01-04 股票： 000155.SZA 出现止损状况
# 日期： 2016-01-04 股票： 002135.SZA 出现止损状况
# 日期： 2016-01-04 股票： 300418.SZA 出现止损状况
# 日期： 2016-01-04 股票： 000688.SZA 出现止损状况
# 日期： 2016-01-05 股票： 000155.SZA 出现止损状况
# 日期： 2016-01-05 股票： 600408.SHA 出现止损状况
# 日期： 2016-01-06 股票： 000155.SZA 出现止损状况
# 日期： 2016-01-07 股票： 000155.SZA 出现止损状况
# 日期： 2016-01-07 股票： 002668.SZA 出现止损状况
# 日期： 2016-01-07 股票： 300441.SZA 出现止损状况
# 日期： 2016-01-07 股票： 300467.SZA 出现止损状况
# 日期： 2016-01-07 股票： 300449.SZA 出现止损状况
# 日期： 2016-01-07 股票： 600768.SHA 出现止损状况
# 日期： 2016-01-07 股票： 002741.SZA 出现止损状况
# 日期： 2016-01-08 股票： 300094.SZA 出现止损状况
# 日期： 2016-01-11 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-11 股票： 300094.SZA 出现止损状况
# 日期： 2016-01-11 股票： 002355.SZA 出现止损状况
# 日期： 2016-01-11 股票： 300189.SZA 出现止损状况
# 日期： 2016-01-11 股票： 000502.SZA 出现止损状况
# 日期： 2016-01-11 股票： 002625.SZA 出现止损状况
# 日期： 2016-01-11 股票： 002592.SZA 出现止损状况
# 日期： 2016-01-11 股票： 002481.SZA 出现止损状况
# 日期： 2016-01-11 股票： 300149.SZA 出现止损状况
# 日期： 2016-01-12 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-13 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-13 股票： 300339.SZA 出现止损状况
# 日期： 2016-01-14 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-15 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-18 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-18 股票： 000917.SZA 出现止损状况
# 日期： 2016-01-18 股票： 000790.SZA 出现止损状况
# 日期： 2016-01-19 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-20 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-21 股票： 300384.SZA 出现止损状况
# 日期： 2016-01-21 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-21 股票： 300092.SZA 出现止损状况
# 日期： 2016-01-21 股票： 300368.SZA 出现止损状况
# 日期： 2016-01-22 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-25 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-26 股票： 000517.SZA 出现止损状况
# 日期： 2016-01-26 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-26 股票： 603600.SHA 出现止损状况
# 日期： 2016-01-26 股票： 300309.SZA 出现止损状况
# 日期： 2016-01-26 股票： 600881.SHA 出现止损状况
# 日期： 2016-01-26 股票： 600683.SHA 出现止损状况
# 日期： 2016-01-27 股票： 002260.SZA 出现止损状况
# 日期： 2016-01-27 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-27 股票： 600694.SHA 出现止损状况
# 日期： 2016-01-28 股票： 002045.SZA 出现止损状况
# 日期： 2016-01-28 股票： 002326.SZA 出现止损状况
# 日期： 2016-01-28 股票： 600866.SHA 出现止损状况
# 日期： 2016-01-28 股票： 600146.SHA 出现止损状况
# 日期： 2016-01-29 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-01 股票： 600432.SHA 出现止损状况
# 日期： 2016-02-01 股票： 002739.SZA 出现止损状况
# 日期： 2016-02-01 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-01 股票： 600881.SHA 出现止损状况
# 日期： 2016-02-01 股票： 601106.SHA 出现止损状况
# 日期： 2016-02-01 股票： 000519.SZA 出现止损状况
# 日期： 2016-02-02 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-03 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-04 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-05 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-15 股票： 600760.SHA 出现止损状况
# 日期： 2016-02-15 股票： 600160.SHA 出现止损状况
# 日期： 2016-02-15 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-15 股票： 601918.SHA 出现止损状况
# 日期： 2016-02-15 股票： 000606.SZA 出现止损状况
# 日期： 2016-02-15 股票： 600226.SHA 出现止损状况
# 日期： 2016-02-15 股票： 000519.SZA 出现止损状况
# 日期： 2016-02-15 股票： 300215.SZA 出现止损状况
# 日期： 2016-02-15 股票： 002205.SZA 出现止损状况
# 日期： 2016-02-16 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-17 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-18 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-19 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-22 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-23 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-24 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-25 股票： 300355.SZA 出现止损状况
# 日期： 2016-02-25 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-25 股票： 000889.SZA 出现止损状况
# 日期： 2016-02-25 股票： 300011.SZA 出现止损状况
# 日期： 2016-02-25 股票： 002373.SZA 出现止损状况
# 日期： 2016-02-25 股票： 002308.SZA 出现止损状况
# 日期： 2016-02-25 股票： 002568.SZA 出现止损状况
# 日期： 2016-02-25 股票： 002261.SZA 出现止损状况
# 日期： 2016-02-26 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-29 股票： 002326.SZA 出现止损状况
# 日期： 2016-02-29 股票： 300310.SZA 出现止损状况
# 日期： 2016-02-29 股票： 002368.SZA 出现止损状况
# 日期： 2016-02-29 股票： 002473.SZA 出现止损状况
# 日期： 2016-02-29 股票： 300245.SZA 出现止损状况
# 日期： 2016-03-01 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-02 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-03 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-04 股票： 300365.SZA 出现止损状况
# 日期： 2016-03-04 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-04 股票： 002228.SZA 出现止损状况
# 日期： 2016-03-07 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-08 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-09 股票： 000973.SZA 出现止损状况
# 日期： 2016-03-09 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-10 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-11 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-14 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-15 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-16 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-17 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-18 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-21 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-22 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-23 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-24 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-25 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-28 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-29 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-30 股票： 002326.SZA 出现止损状况
# 日期： 2016-03-31 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-01 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-05 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-06 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-07 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-08 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-11 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-12 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-12 股票： 000066.SZA 出现止损状况
# 日期： 2016-04-13 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-14 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-15 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-18 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-19 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-20 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-21 股票： 300028.SZA 出现止损状况
# 日期： 2016-04-21 股票： 002326.SZA 出现止损状况
# 日期： 2016-04-25 股票： 600654.SHA 出现止损状况
# 日期： 2016-05-09 股票： 600265.SHA 出现止损状况
# 日期： 2016-05-09 股票： 002326.SZA 出现止损状况
# 日期： 2016-05-09 股票： 600745.SHA 出现止损状况
# 日期： 2016-05-10 股票： 600265.SHA 出现止损状况
# 日期： 2016-05-11 股票： 600265.SHA 出现止损状况
# 日期： 2016-05-12 股票： 600265.SHA 出现止损状况
# 日期： 2016-05-18 股票： 002018.SZA 出现止损状况
# 日期： 2016-06-13 股票： 600247.SHA 出现止损状况
# 日期： 2016-06-13 股票： 600365.SHA 出现止损状况
# 日期： 2016-06-14 股票： 600247.SHA 出现止损状况
# 日期： 2016-06-20 股票： 600250.SHA 出现止损状况
# 日期： 2016-07-22 股票： 600556.SHA 出现止损状况
# 日期： 2016-07-25 股票： 600581.SHA 出现止损状况
# 日期： 2016-07-27 股票： 002034.SZA 出现止损状况
# 日期： 2016-08-01 股票： 600556.SHA 出现止损状况
# 日期： 2016-08-02 股票： 600556.SHA 出现止损状况
# 日期： 2016-08-03 股票： 600556.SHA 出现止损状况
# 日期： 2016-08-04 股票： 600556.SHA 出现止损状况
# 日期： 2016-08-05 股票： 600556.SHA 出现止损状况
# 日期： 2016-08-08 股票： 600556.SHA 出现止损状况
# 日期： 2016-09-26 股票： 300372.SZA 出现止损状况
# 日期： 2016-09-27 股票： 300372.SZA 出现止损状况
# 日期： 2016-09-28 股票： 300372.SZA 出现止损状况
# 日期： 2016-09-29 股票： 300372.SZA 出现止损状况
# 日期： 2016-09-30 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-10 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-11 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-12 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-13 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-14 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-17 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-18 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-19 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-20 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-21 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-24 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-25 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-26 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-27 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-28 股票： 300372.SZA 出现止损状况
# 日期： 2016-10-31 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-01 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-02 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-03 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-04 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-07 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-08 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-09 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-10 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-11 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-14 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-15 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-16 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-17 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-18 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-21 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-22 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-23 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-24 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-25 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-28 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-29 股票： 300372.SZA 出现止损状况
# 日期： 2016-11-30 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-01 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-02 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-05 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-06 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-07 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-08 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-09 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-12 股票： 300211.SZA 出现止损状况
# 日期： 2016-12-12 股票： 002703.SZA 出现止损状况
# 日期： 2016-12-12 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-13 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-14 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-15 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-16 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-19 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-20 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-21 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-22 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-23 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-26 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-27 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-28 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-29 股票： 300372.SZA 出现止损状况
# 日期： 2016-12-30 股票： 300372.SZA 出现止损状况
# [2019-05-09 10:52:10.362350] INFO: Performance: Simulated 488 trading days out of 488.
# [2019-05-09 10:52:10.365004] INFO: Performance: first open: 2015-01-05 09:30:00+00:00
# [2019-05-09 10:52:10.366687] INFO: Performance: last close: 2016-12-30 15:00:00+00:00
# <div id='bigchart-a9f5d12c55804599a0dbdd8bd03b1e63' class='bigchart display' style='display:none'><ul class='nav nav-tabs' style='padding-left: 0;'><li class='tabtitle' style='margin: 0;'><span style='margin: 0;font-size: 1.2em;display: inline-block;padding: 10px 10px;'>Trade(回测/模拟)</span></li><li class='active'><a>收益概况</a></li><li><a>交易详情</a></li><li><a>每日持仓和收益</a></li><li><a>输出日志</a></li></ul><div class='tab-content' style='min-height: 100px;text-align: center;'><div class='tab-pane active' id='收益概况'>
# <div class='kpicontainer'>
#     <ul class='kpi'>
#         <li><span class='title'>收益率</span><span class='value'>302.33%</span></li>
#         <li><span class='title'>年化收益率</span><span class='value'>105.21%</span></li>
#         <li><span class='title'>基准收益率</span><span class='value'>-6.33%</span></li>
#         <li><span class='title'>阿尔法</span><span class='value'>0.8</span></li>
#         <li><span class='title'>贝塔</span><span class='value'>0.97</span></li>
#         <li><span class='title'>夏普比率</span><span class='value'>1.78</span></li>
#         <li><span class='title'>胜率</span><span class='value'>0.62</span></li>
#         <li><span class='title'>盈亏比</span><span class='value'>0.93</span></li>
#         <li><span class='title'>收益波动率</span><span class='value'>44.26%</span></li>
#         <li><span class='title'>信息比率</span><span class='value'>0.16</span></li>
#         <li><span class='title'>最大回撤</span><span class='value'>52.06%</span></li>
#     </ul>
# </div>
# <div id="bigchart-22db7203bde64d8aab8ba1a3b318103a" class="bigchart"></div><div class="bigchart-data"><pre style="display:none">bigcharts-data-start/{"navigator":{"enabled":true},"plotOptions":{"series":{"showInNavigator":true},"area":{"showInNavigator":true}},"chart":{"height":400,"renderTo":"bigchart-22db7203bde64d8aab8ba1a3b318103a"},"legend":{"symbolRadius":0,"symbolWidth":8,"symbolHeight":8,"symbolPadding":8,"enabled":true},"stock":true,"xAxis":{"type":"datetime"},"rangeSelector":{"enabled":true},"yAxis":[{"title":{"text":"\u51c0\u503c\u66f2\u7ebf"},"labels":{"align":"right","x":-3,"format":"{value}%"},"gridLineColor":"#cfcfcf","top":"0%","lineWidth":2,"gridLineWidth":1,"height":"62%","offset":0},{"title":{"text":"\u6301\u4ed3\u5360\u6bd4"},"labels":{"align":"right","x":-3,"format":"{value}%"},"gridLineColor":"#cfcfcf","top":"66%","lineWidth":2,"gridLineWidth":1,"height":"15%","offset":0},{"title":{"text":"\u81ea\u5b9a\u4e49\u6570\u636e"},"labels":{"align":"right","x":-3},"gridLineColor":"#cfcfcf","top":"85%","lineWidth":2,"gridLineWidth":1,"height":"15%","offset":0}],"series